# %% [markdown]
# # KlassenDiagram

# %% [markdown]
# **Bovenvak = Class**
#
# **Middenvak = Fields**
#
# **Ondervak = Methodes**

# %% [markdown]
# `<<abstract>>`
#
# Abstract Class name: `Sensor`
#
# `<<interface>>`
#
# Class name: `ISensor`
# `<<enum>>`
#
# Enum: `Numbers`

# %% [markdown]
# `+ public`
#
# `- private`
#
# `# protected`

# %% [markdown]
# `GetNumber():double` = output
#
# `Class Sensor` - `Sensor(string)` = Constructor
#
# `GetName(string)` = input

# %% [markdown]
# Schuine woorden = abstracte methode
#
# vb: ***Abstract methode***

# %% [markdown]
# # Soorten links
#
# `_________` = Associatie
#
# `________>` = Overerving
#
# `-------->` = Polymorfisme
#
# `Ruit Hol` = Aggregatie
#
# `Ruit Vol` = Compositie

# %% [markdown]
# # Relatie soort
#
# `2` langs aangeduide zijde
#
# `1..*` of meer lans aangeduide zijde
#
# `4..* 4` of meer langs aangeduide zijde
#
# `*<(of 0..*)` 0 of meer langs aangeduide zijde
#
# `8..12` 8 tot 12 langs aangeduide zijde
